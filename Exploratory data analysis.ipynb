# %%
pip install tabulate
# Out:
# ...
# Note: you may need to restart the kernel to use updated packages.

# %%
import matplotlib.pyplot as plt 
from tabulate import tabulate 
import matplotlib as mat 
import seaborn as sns 
import pandas as pd 
import numpy as np

# %%
pwd
# Out:
# 'C:\\Users\\Admin\\Downloads'

# %%
df = pd.read_csv("data.csv")
df
# Out:
#                  city  area  rooms  bathroom  parking spaces  floor  \
# 0           São Paulo    70      2         1               1      7
# 1           São Paulo   320      4         4               0     20
# 2        Porto Alegre    80      1         1               1      6
# 3        Porto Alegre    51      2         1               0      2
# 4           São Paulo    25      1         1               0      1
# ...               ...   ...    ...       ...             ...    ...
# 10687    Porto Alegre    63      2         1               1      5
# 10688       São Paulo   285      4         4               4     17
# 10689  Rio de Janeiro    70      3         3               0      8
# 10690  Rio de Janeiro   120      2         2               2      8
# 10691       São Paulo    80      2         1               0      0
#
#           animal      furniture  hoa (R$)  rent amount (R$)  \
# 0          acept      furnished      2065              3300
# ...

# %%
df.head()
# Out:
#            city  area  rooms  bathroom  parking spaces  floor     animal  \
# 0     São Paulo    70      2         1               1      7      acept
# 1     São Paulo   320      4         4               0     20      acept
# 2  Porto Alegre    80      1         1               1      6      acept
# 3  Porto Alegre    51      2         1               0      2      acept
# 4     São Paulo    25      1         1               0      1  not acept
#
#        furniture   hoa  rent_amount  property_tax   fire_insurance  total
# 0      furnished  2065         3300            211              42   5618
# 1  not furnished  1200         4960           1750              63   7973
# 2  not furnished  1000         2800              0              41   3841
# 3  not furnished   270         1112             22              17   1421
# 4  not furnished     0          800             25              11    836

# %%
df.tail()
# Out:
#                  city  area  rooms  bathroom  parking spaces  floor  \
# 10687    Porto Alegre    63      2         1               1      5
# 10688       São Paulo   285      4         4               4     17
# 10689  Rio de Janeiro    70      3         3               0      8
# 10690  Rio de Janeiro   120      2         2               2      8
# 10691       São Paulo    80      2         1               0      0
#
#           animal      furniture   hoa  rent_amount  property_tax   \
# 10687  not acept      furnished   402         1478             24
# 10688      acept  not furnished  3100        15000            973
# 10689  not acept      furnished   980         6000            332
# 10690      acept      furnished  1585        12000            279
# 10691      acept  not furnished     0         1400            165
#
#        fire_insurance  total
# 10687              22   1926
# 10688             191  19260
# 10689              78   7390
# 10690             155  14020
# ...

# %%
print(df.shape)
# Out:
# (10692, 13)

# %%
print(df.columns)
# Out:
# Index(['city', 'area', 'rooms', 'bathroom', 'parking spaces', 'floor',
#        'animal', 'furniture', 'hoa', 'rent_amount', 'property_tax ',
#        'fire_insurance', 'total'],
#       dtype='object')

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 10692 entries, 0 to 10691
# Data columns (total 13 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   city            10692 non-null  object
#  1   area            10692 non-null  int64
#  2   rooms           10692 non-null  int64
#  3   bathroom        10692 non-null  int64
#  4   parking spaces  10692 non-null  int64
#  5   floor           10692 non-null  int64
#  6   animal          10692 non-null  object
#  7   furniture       10692 non-null  object
#  8   hoa             10692 non-null  int64
#  9   rent_amount     10692 non-null  int64
#  10  property_tax    10692 non-null  int64
#  11  fire_insurance  10692 non-null  int64
#  12  total           10692 non-null  int64
# dtypes: int64(10), object(3)
# memory usage: 1.1+ MB

# %%
df.isnull().sum()
# Out:
# city              0
# area              0
# rooms             0
# bathroom          0
# parking spaces    0
# floor             0
# animal            0
# furniture         0
# hoa               0
# rent_amount       0
# property_tax      0
# fire_insurance    0
# total             0
# dtype: int64

# %%
def seprate_data_types(df):
 categorical = []
 continuous = []
 for column in df.columns: 
    if df[column].nunique() < 43: 
      categorical.append(column)
    else:
      continuous.append(column)
 
 return categorical, continuous
categorical, continuous = seprate_data_types(df)
table = [categorical, continuous]
print(tabulate({"Categorical":categorical,
 "Continuous": continuous}, headers = ["categorical", 
"continuous"]))
# Out:
# categorical     continuous
# --------------  --------------
# city            area
# rooms           hoa
# bathroom        rent_amount
# parking spaces  property_tax
# floor           fire_insurance
# animal          total
# furniture

# %% [markdown]
# # 𝑼𝒏𝒊𝒗𝒂𝒓𝒊𝒂𝒕𝒆 𝑨𝒏𝒂𝒍𝒂𝒚𝒔𝒊𝒔 𝒐𝒇 𝑪𝒂𝒕𝒆𝒈𝒐𝒓𝒊𝒄𝒂𝒍 𝑽𝒂𝒓𝒊𝒂𝒃𝒍𝒆�

# %%
def info_of_cat(col): 
 print(f"Unique values in {col} are: {df[col].unique()}")
 print(f"Mode of {col} is {df[col].mode()[0]}") 
 print(f"Number of missing values in {col} is {df[col].isnull().sum()}")
 if df[col].isnull().sum() > 0:
    print(f"\nThere is a null values in the {col}")

# %%
info_of_cat('city')
# Out:
# Unique values in city are: ['São Paulo' 'Porto Alegre' 'Rio de Janeiro' 'Campinas' 'Belo Horizonte']
# Mode of city is São Paulo
# Number of missing values in city is 0

# %% [markdown]
# # 1.analysis of city

# %%
fig, ax = plt.subplots(1, 2, figsize = (15, 7))
ax[0].set_title("city") 
percentage = df["city"].value_counts() 
labels = list(df["city"].value_counts().index) 
sns.countplot(x = df["city"], ax = ax[0])
plt.pie(percentage,labels = labels, autopct= "%0.2f%%") 
 
plt.show()

# %% [markdown]
# # Interpretation : sao paulo is more in  number of count by 55.06%

# %% [markdown]
# # 2.analysis of rooms

# %%
info_of_cat('rooms')
# Out:
# Unique values in rooms are: [ 2  4  1  3  7  5  8  6 10 13  9]
# Mode of rooms is 3
# Number of missing values in rooms is 0

# %%
fig, ax = plt.subplots(1, 2, figsize = (15, 7))
ax[0].set_title("rooms") 
percentage = df["rooms"].value_counts() 
labels = list(df["rooms"].value_counts().index) 
sns.countplot(x = df["rooms"], ax = ax[0])
plt.pie(percentage,labels = labels, autopct= "%0.2f%%") 
 
plt.show()

# %% [markdown]
# # Interpretation : their are more rooms with count 3 and 2 by 58.39%

# %% [markdown]
# # 3. analysis of bathroom

# %%
info_of_cat('bathroom')
# Out:
# Unique values in bathroom are: [ 1  4  3  2  6  5  7  9  8 10]
# Mode of bathroom is 1
# Number of missing values in bathroom is 0

# %%
fig, ax = plt.subplots(1, 2, figsize = (15, 7))
ax[0].set_title("bathroom") 
percentage = df["bathroom"].value_counts() 
labels = list(df["bathroom"].value_counts().index) 
sns.countplot(x = df["bathroom"], ax = ax[0])
plt.pie(percentage,labels = labels, autopct= "%0.2f%%") 
 
plt.show()

# %% [markdown]
# # Interpretation :  their are more number of bathroom with count 1 by 40.23%

# %% [markdown]
# # 4. analysis of parking spaces

# %%
info_of_cat('parking spaces')
# Out:
# Unique values in parking spaces are: [ 1  0  7  4  2  6  3  8  5 10 12]
# Mode of parking spaces is 1
# Number of missing values in parking spaces is 0

# %%
fig, ax = plt.subplots(1, 2, figsize = (15, 7))
ax[0].set_title("parking spaces") 
percentage = df["parking spaces"].value_counts() 
labels = list(df["parking spaces"].value_counts().index) 
sns.countplot(x = df["parking spaces"], ax = ax[0])
plt.pie(percentage,labels = labels, autopct= "%0.2f%%") 
 
plt.show()

# %% [markdown]
# # Interpretation : their are more number of parking spaces with count 1 and 0 by 59.04%

# %% [markdown]
# # 5.analysis of floor

# %%
info_of_cat('floor')
# Out:
# Unique values in floor are: [  7  20   6   2   1   0   4   3  10  11  24   9   8  17  18   5  13  15
#   16  14  26  12  21  19  22  27  23  35  25  46  28  29 301  51  32]
# Mode of floor is 0
# Number of missing values in floor is 0

# %%
fig, ax = plt.subplots(1, 2, figsize = (15, 7))
ax[0].set_title("floor") 
percentage = df["floor"].value_counts() 
labels = list(df["floor"].value_counts().index) 
sns.countplot(x = df["floor"], ax = ax[0])
plt.pie(percentage,labels = labels, autopct= "%0.2f%%") 
 
plt.show()

# %% [markdown]
# # Interpretation : their are more of floors with count 1 and 0 by 43.23%

# %% [markdown]
# # 6. analysis of animals

# %%
info_of_cat('animal')
# Out:
# Unique values in animal are: ['acept' 'not acept']
# Mode of animal is acept
# Number of missing values in animal is 0

# %%
fig, ax = plt.subplots(1, 2, figsize = (15, 7))
ax[0].set_title("animal") 
percentage = df["animal"].value_counts() 
labels = list(df["animal"].value_counts().index) 
sns.countplot(x = df["animal"], ax = ax[0])
plt.pie(percentage,labels = labels, autopct= "%0.2f%%") 
 
plt.show()

# %% [markdown]
# # Interpretation : the animal acceptance rate is higher than the not acceptance rate by 77.78%

# %% [markdown]
# # 7.analysis of furniture

# %%
info_of_cat('furniture')
# Out:
# Unique values in furniture are: ['furnished' 'not furnished']
# Mode of furniture is not furnished
# Number of missing values in furniture is 0

# %%
fig, ax = plt.subplots(1, 2, figsize = (15, 7))
ax[0].set_title("furniture") 
percentage = df["furniture"].value_counts() 
labels = list(df["furniture"].value_counts().index) 
sns.countplot(x = df["furniture"], ax = ax[0])
plt.pie(percentage,labels = labels, autopct= "%0.2f%%") 
 
plt.show()

# %% [markdown]
# # Interpretation : their are more buildings which provide not furnished area by 75.63%than the furnished ones

# %% [markdown]
# # 𝑼𝒏𝒊𝒗𝒂𝒓𝒊𝒂𝒕𝒆 𝑨𝒏𝒂𝒍𝒂𝒚𝒔𝒊𝒔 𝒐𝒇 𝑵𝒖𝒎𝒆𝒓𝒊𝒄𝒂𝒍 𝑽𝒂𝒓𝒊𝒂𝒃𝒍𝒆�

# %%
def info_of_numerical(col):
 print(f"The mean of the {col} is {df[col].mean()}")
 print(f"The median of the {col} is {df[col].median()}")
 print(f"The standard deviation of the {col} is {df[col].std()}")
 print(f"Number of missing values in the {col} is {df[col].isnull().sum()}")

# %% [markdown]
# # 8.analysis of area

# %%
info_of_numerical('area')
# Out:
# The mean of the area is 149.21791994014217
# The median of the area is 90.0
# The standard deviation of the area is 537.0169423364867
# Number of missing values in the area is 0

# %% [markdown]
# # outlier treatment

# %%
mean = int(df.area.mean())
# accessing the data higher than 6
x = df[df["area"] > 1000].index
for index in x:
    df.loc[index, "area"] = mean

# %%
fig, ax = plt.subplots(1, 2, figsize= (20, 7)) 
sns.histplot(x = df["area"], ax =ax[1], color = "m") 
sns.boxplot(x = df["area"], ax = ax[0], color = "g") 
plt.show()

# %% [markdown]
# # Interpretation : the area rate is highest between 50 to 100

# %% [markdown]
# # 9.analysis of hoa

# %%
info_of_numerical('hoa')
# Out:
# The mean of the hoa is 1174.0216984661429
# The median of the hoa is 560.0
# The standard deviation of the hoa is 15592.305248403356
# Number of missing values in the hoa is 0

# %% [markdown]
# # outlier treatment

# %%
mean = int(df.hoa.mean())
# accessing the data higher than 6
x = df[df["hoa"] >= 6000].index
for index in x:
    df.loc[index, "hoa"] = mean

# %%
fig, ax = plt.subplots(1, 2, figsize= (20, 7)) 
sns.histplot(x = df["hoa"], ax =ax[1], color = "m") 
sns.boxplot(x = df["hoa"], ax = ax[0], color = "g") 
plt.show()

# %% [markdown]
# # Interpretation : the hoa rate is highest between 0 to 1000

# %% [markdown]
# # 10. analysis of rent amount

# %%
info_of_numerical('rent_amount')
# Out:
# The mean of the rent_amount is 3896.247194163861
# The median of the rent_amount is 2661.0
# The standard deviation of the rent_amount is 3408.5455176710816
# Number of missing values in the rent_amount is 0

# %% [markdown]
# # outlier treatment

# %%
mean = int(df.rent_amount.mean())
# accessing the data higher than 6
x = df[df["rent_amount"] >= 20000].index
for index in x:
    df.loc[index, "rent_amount"] = mean

# %%
fig, ax = plt.subplots(1, 2, figsize= (20, 7)) 
sns.histplot(x = df["rent_amount"], ax =ax[1], color = "m") 
sns.boxplot(x = df["rent_amount"], ax = ax[0], color = "g") 
plt.show()

# %% [markdown]
# # Interpretation : the rent amount rate is highest between 500 to 3000

# %% [markdown]
# # 11.analysis of property tax

# %% [markdown]
# # outlier treatment

# %%
mean = int(df['property_tax '].mean())
# accessing the data higher than 6
x = df[df["property_tax "] >= 1000].index
for index in x:
    df.loc[index, "property_tax "] = mean

# %%
fig, ax = plt.subplots(1, 2, figsize= (20, 7)) 
sns.histplot(x = df["property_tax "], ax =ax[1], color = "m") 
sns.boxplot(x = df["property_tax "], ax = ax[0], color = "g") 
plt.show()

# %% [markdown]
# # Interpretation : the property tax is highest between 0 to 200

# %% [markdown]
# # 12. analysis of fire insurance

# %%
info_of_numerical('fire_insurance')
# Out:
# The mean of the fire_insurance is 53.300879161990274
# The median of the fire_insurance is 36.0
# The standard deviation of the fire_insurance is 47.768030930197206
# Number of missing values in the fire_insurance is 0

# %% [markdown]
# # outlier treatment

# %%
mean = int(df['fire_insurance'].mean())
# accessing the data higher than 6
x = df[df["fire_insurance"] >= 200].index
for index in x:
    df.loc[index, "fire_insurance"] = mean

# %%
fig, ax = plt.subplots(1, 2, figsize= (20, 7)) 
sns.histplot(x = df["fire_insurance"], ax =ax[1], color = "m") 
sns.boxplot(x = df["fire_insurance"], ax = ax[0], color = "g") 
plt.show()

# %% [markdown]
# # Interpretation : the fire insurance rate is highest between 0 to 50

# %% [markdown]
# # 13. analysis of total

# %%
info_of_numerical('total')
# Out:
# The mean of the total is 5490.4869996258885
# The median of the total is 3581.5
# The standard deviation of the total is 16484.72591235027
# Number of missing values in the total is 0

# %% [markdown]
# # outlier treatment

# %%
mean = int(df['total'].mean())
#accessing the data higher than 6
x = df[df["total"] >= 14000].index
for index in x:
    df.loc[index, "total"] = mean

# %%
fig, ax = plt.subplots(1, 2, figsize= (20, 7)) 
sns.histplot(x = df["total"], ax =ax[1], color = "m") 
sns.boxplot(x = df["total"], ax = ax[0], color = "g") 
plt.show()

# %% [markdown]
# # Interpretation : the total rate is between 1000 to 4000

# %% [markdown]
# # bivariate analysis

# %% [markdown]
# cat - cat analysis

# %% [markdown]
# # 14.analysis of city with rooms

# %%
fig, ax = plt.subplots(figsize = (20, 7))
sns.countplot(x = "city", hue = "rooms", data = df)
plt.show()

# %%
city_mean = df["rooms"].groupby(df["city"]).mean()

# %%
city_mean.plot(kind='bar', title='Arrests', ylabel='Mean',
         xlabel='cities', figsize=(6, 5))
# Out:
# <AxesSubplot:title={'center':'Arrests'}, xlabel='cities', ylabel='Mean'>

# %% [markdown]
# # Interpretation : belo horizonte has higher room mean than anyother city

# %% [markdown]
# # 15.analysis of city with bathrooms

# %%
fig, ax = plt.subplots(figsize = (15, 10))
sns.countplot(x = "city", hue = "bathroom", data = df)
plt.show()

# %%
bathroom = df["bathroom"].groupby(df["city"]).mean()

# %%
bathroom.plot(kind='bar', title='Arrests', ylabel='Mean',
         xlabel='cities', figsize=(6, 5))
# Out:
# <AxesSubplot:title={'center':'Arrests'}, xlabel='cities', ylabel='Mean'>

# %% [markdown]
# # Interpretation : sao paulo has high number of bathroom mean rate

# %% [markdown]
# # 16.analysis of city with parking spaces

# %%
fig, ax = plt.subplots(figsize = (15, 10))
sns.countplot(x = "city", hue = "parking spaces", data = df)
plt.show()

# %%
p_space = df["parking spaces"].groupby(df["city"]).mean()

# %%
p_space.plot(kind='bar', title='Arrests', ylabel='Mean',
         xlabel='cities', figsize=(6, 5))
# Out:
# <AxesSubplot:title={'center':'Arrests'}, xlabel='cities', ylabel='Mean'>

# %% [markdown]
# # Interpretation : belo horizonte provides higher parking space mean than anyother city

# %% [markdown]
# # 17.analysis of city with floor

# %%
fig, ax = plt.subplots(figsize = (15, 10))
sns.countplot(x = "city", hue = "floor", data = df)
plt.show()

# %%
floor = df["floor"].groupby(df["city"]).mean()

# %%
floor.plot(kind='bar', title='Arrests', ylabel='Mean',
         xlabel='cities', figsize=(6, 5))
# Out:
# <AxesSubplot:title={'center':'Arrests'}, xlabel='cities', ylabel='Mean'>

# %% [markdown]
# # Interpretation : sao paulo provides higher floor mean rate than any other city

# %% [markdown]
# # 18.analysis of city with animal

# %%
fig, ax = plt.subplots(figsize = (15, 10))
sns.countplot(x = "city", hue = "animal", data = df)
plt.show()

# %% [markdown]
# based on graph sao paulo has highest acceptance rate

# %%
df["animal"].groupby(df["city"]).value_counts()
# Out:
# city            animal
# Belo Horizonte  acept         931
#                 not acept     327
# Campinas        acept         693
#                 not acept     160
# Porto Alegre    acept        1005
#                 not acept     188
# Rio de Janeiro  acept        1205
#                 not acept     296
# São Paulo       acept        4482
#                 not acept    1405
# Name: animal, dtype: int64

# %%
print(f"Belo Horizonte : {round(931/(931+327)*100,2)}%")
print(f" Campinas   : {round(693/(693+160+24)*100,2)}%")
print(f"Porto Alegre: {round(1005/(1005+188)*100,2)}%")
print(f"Rio de Janeiro : {round(1205/(1205+296)*100,2)}%")
print(f"São Paulo: {round(4482/(4482+1405)*100,2)}%")
# Out:
# Belo Horizonte : 74.01%
#  Campinas   : 79.02%
# Porto Alegre: 84.24%
# Rio de Janeiro : 80.28%
# São Paulo: 76.13%

# %% [markdown]
# # Interpretation : based on percentage porto alegre has has highest acceptance rate

# %% [markdown]
# # 19.analysis of city with furniture

# %%
fig, ax = plt.subplots(figsize = (15, 10))
sns.countplot(x = "city", hue = "furniture", data = df)
plt.show()

# %% [markdown]
# sao paulo has highest furnished rate

# %%
df["furniture"].groupby(df["city"]).value_counts()
# Out:
# city            furniture
# Belo Horizonte  not furnished    1081
#                 furnished         177
# Campinas        not furnished     742
#                 furnished         111
# Porto Alegre    not furnished     874
#                 furnished         319
# Rio de Janeiro  not furnished    1095
#                 furnished         406
# São Paulo       not furnished    4294
#                 furnished        1593
# Name: furniture, dtype: int64

# %%
print(f"Belo Horizonte : {round(177/(177+1081)*100,2)}%")
print(f" Campinas   : {round(111/(111+742)*100,2)}%")
print(f"Porto Alegre: {round(319/(319+874)*100,2)}%")
print(f"Rio de Janeiro : {round(406/(406+1095)*100,2)}%")
print(f"São Paulo: {round(1593/(1593+4294)*100,2)}%")
# Out:
# Belo Horizonte : 14.07%
#  Campinas   : 13.01%
# Porto Alegre: 26.74%
# Rio de Janeiro : 27.05%
# São Paulo: 27.06%

# %% [markdown]
# # Interpretation : de janeiro has or provides more furnished buildings or places as it has higher mean

# %% [markdown]
# cat - num analysis

# %% [markdown]
# # 20. analysis of city and area

# %%
df["area"].groupby(df["city"]).mean()
# Out:
# city
# Belo Horizonte    167.062798
# Campinas          122.810082
# Porto Alegre      103.609388
# Rio de Janeiro    105.347768
# São Paulo         154.090538
# Name: area, dtype: float64

# %%
df["area"].groupby(df["city"]).mean().hist()
# Out:
# <AxesSubplot:>

# %%
area = df["area"].groupby(df["city"]).mean()

area.plot(kind='bar', title='Arrests', ylabel='Mean',
         xlabel='cities', figsize=(6, 5))
# Out:
# <AxesSubplot:title={'center':'Arrests'}, xlabel='cities', ylabel='Mean'>

# %%
fig, ax = plt.subplots(1, 2, figsize = (15, 7))
sns.histplot(x = df["area"], hue = df["city"], ax = ax[0])
sns.boxplot(x = df["city"] ,y = df["area"] , ax = ax[1])
plt.show()

# %% [markdown]
# # Interpretation :  belo horizonte provides higher area mean than any other city

# %% [markdown]
# # 21. analysis of city and hoa

# %%
df["hoa"].groupby(df["city"]).mean()
# Out:
# city
# Belo Horizonte     545.096979
# Campinas           621.623681
# Porto Alegre       460.896060
# Rio de Janeiro    1019.355763
# São Paulo         1036.350093
# Name: hoa, dtype: float64

# %%
hoa = df["hoa"].groupby(df["city"]).mean() 

hoa.plot(kind='bar', title='Arrests', ylabel='Mean',
         xlabel='cities', figsize=(6, 5))
# Out:
# <AxesSubplot:title={'center':'Arrests'}, xlabel='cities', ylabel='Mean'>

# %%
fig, ax = plt.subplots(1, 2, figsize = (15, 7))
sns.histplot(x = df["hoa"], hue = df["city"], ax = ax[0])
sns.boxplot(x = df["city"] ,y = df["hoa"] , ax = ax[1])
plt.show()

# %% [markdown]
# # Interpretation : rio de janeiro and sao paulo has higher hoa than other cities

# %% [markdown]
# # 22.analysis of city and rent amount

# %%
df["rent_amount"].groupby(df["city"]).mean()
# Out:
# city
# Belo Horizonte    3664.127981
# Campinas          2364.290739
# Porto Alegre      2337.699916
# Rio de Janeiro    3232.904064
# São Paulo         4620.700017
# Name: rent_amount, dtype: float64

# %%
rent = df["rent_amount"].groupby(df["city"]).mean() 

rent.plot(kind='bar', title='Arrests', ylabel='Mean',
         xlabel='cities', figsize=(6, 5))
# Out:
# <AxesSubplot:title={'center':'Arrests'}, xlabel='cities', ylabel='Mean'>

# %%
fig, ax = plt.subplots(1, 2, figsize = (15, 7))
sns.histplot(x = df["rent_amount"], hue = df["city"], ax = ax[0])
sns.boxplot(x = df["city"] ,y = df["rent_amount"] , ax = ax[1])
plt.show()

# %% [markdown]
# # Interpretation : sao paulo has higher rent amount rate than other cities

# %% [markdown]
# # 23. analysis of city and property tax

# %%
df["property_tax "].groupby(df["city"]).mean()
# Out:
# city
# Belo Horizonte    213.977742
# Campinas          136.852286
# Porto Alegre      105.637888
# Rio de Janeiro    191.976682
# São Paulo         241.849329
# Name: property_tax , dtype: float64

# %%
mean = df["property_tax "].groupby(df["city"]).mean() 

mean.plot(kind='bar', title='Arrests', ylabel='Mean',
         xlabel='cities', figsize=(6, 5))
# Out:
# <AxesSubplot:title={'center':'Arrests'}, xlabel='cities', ylabel='Mean'>

# %%
mean = int(df['property_tax '].mean())
# accessing the data higher than 6
x = df[df["property_tax "] >= 1000].index
for index in x:
    df.loc[index, "property_tax "] = mean

# %%
fig, ax = plt.subplots(1, 2, figsize = (15, 7))
sns.histplot(x = df["property_tax "], hue = df["city"], ax = ax[0])
sns.boxplot(x = df["city"] ,y = df["property_tax "] , ax = ax[1])
plt.show()

# %% [markdown]
# # Interpretation : sao paulo has higher property tax mean

# %% [markdown]
# # 24. analysis of city and fire insurance

# %%
 df["fire_insurance"].groupby(df["city"]).mean()
# Out:
# city
# Belo Horizonte    47.180445
# Campinas          31.621336
# Porto Alegre      34.331098
# Rio de Janeiro    41.320453
# São Paulo         59.568711
# Name: fire_insurance, dtype: float64

# %%
mean = df["fire_insurance"].groupby(df["city"]).mean() 

mean.plot(kind='bar', title='Arrests', ylabel='Mean',
         xlabel='cities', figsize=(6, 5))
# Out:
# <AxesSubplot:title={'center':'Arrests'}, xlabel='cities', ylabel='Mean'>

# %%
mean = int(df['fire_insurance'].mean())
# accessing the data higher than 6
x = df[df["fire_insurance"] > 200].index
for index in x:
    df.loc[index, "fire_insurance"] = mean

# %%
fig, ax = plt.subplots(1, 2, figsize = (15, 7))
sns.histplot(x = df["fire_insurance"], hue = df["city"], ax = ax[0])
sns.boxplot(x = df["city"] ,y = df["fire_insurance"] , ax = ax[1])
plt.show()

# %% [markdown]
# # Interpretation : sao paulo has higher fire insurance mean

# %% [markdown]
# # 25. analysis of city and total

# %%
df["total"].groupby(df["city"]).mean()
# Out:
# city
# Belo Horizonte    3925.798887
# Campinas          3032.092614
# Porto Alegre      2829.673931
# Rio de Janeiro    4095.502332
# São Paulo         5151.608120
# Name: total, dtype: float64

# %%
mean = df["total"].groupby(df["city"]).mean() 

mean.plot(kind='bar', title='Arrests', ylabel='Mean',
         xlabel='cities', figsize=(6, 5))
# Out:
# <AxesSubplot:title={'center':'Arrests'}, xlabel='cities', ylabel='Mean'>

# %%
mean = int(df['total'].mean())
# accessing the data higher than 6
x = df[df["total"] > 14000].index
for index in x:
    df.loc[index, "total"] = mean

# %% [markdown]
# # Interpretation : sao paulo has higher total mean than any other cities

# %% [markdown]
# # multivariate analysis

# %% [markdown]
# # 26.analysis of city who has more area with less total?

# %%
data= df[(df.area > df['area'].mean())]
data
# Out:
#                city  area  rooms  bathroom  parking spaces  floor     animal  \
# 1         São Paulo   320      4         4               0     20      acept
# 5         São Paulo   376      3         3               7      0      acept
# 7         São Paulo   213      4         4               4      4      acept
# 8         São Paulo   152      2         2               1      3      acept
# 15         Campinas   330      4         6               6      0      acept
# ...             ...   ...    ...       ...             ...    ...        ...
# 10681     São Paulo   230      3         5               3      3  not acept
# 10682  Porto Alegre   160      3         2               3      4      acept
# 10683     São Paulo   280      4         4               2      5      acept
# 10686     São Paulo   150      3         3               2      8  not acept
# 10688     São Paulo   285      4         4               4     17      acept
#
# ...

# %%
mean = int(df['total'].mean())
# accessing the data higher than 6
x = df[df["total"] > 14000].index
for index in x:
    df.loc[index, "total"] = mean

# %%
fig, ax = plt.subplots(1, 2, figsize = (15, 7))
sns.histplot(x = df["total"], hue = df["city"], ax = ax[0])
sns.boxplot(x = df["city"] ,y = df["total"] , ax = ax[1])
plt.show()

# %%
data["total"].groupby(data["city"]).mean()
# Out:
# city
# Belo Horizonte    6336.686424
# Campinas          5885.827586
# Porto Alegre      5783.764706
# Rio de Janeiro    7184.083333
# São Paulo         7460.186644
# Name: total, dtype: float64

# %%
mean = data["total"].groupby(data["city"]).mean()

mean.plot(kind='bar', title='Arrests', ylabel='Mean',
         xlabel='cities', figsize=(6, 5))
# Out:
# <AxesSubplot:title={'center':'Arrests'}, xlabel='cities', ylabel='Mean'>

# %% [markdown]
# # porto alegre has or provides more "area" place with less "total" mean

# %% [markdown]
# # 27.analysis which city provides more rooms with less total

# %%
 df['rooms'].mean()
# Out:
# 2.506079311634867

# %%
data_1 = df[(df.rooms > df['rooms'].mean())]
data_1
# Out:
#                  city  area  rooms  bathroom  parking spaces  floor  \
# 1           São Paulo   320      4         4               0     20
# 5           São Paulo   376      3         3               7      0
# 7           São Paulo   213      4         4               4      4
# 15           Campinas   330      4         6               6      0
# 19          São Paulo   600      4         5               6      0
# ...               ...   ...    ...       ...             ...    ...
# 10683       São Paulo   280      4         4               2      5
# 10685       São Paulo    83      3         2               2     11
# 10686       São Paulo   150      3         3               2      8
# 10688       São Paulo   285      4         4               4     17
# 10689  Rio de Janeiro    70      3         3               0      8
#
#           animal      furniture   hoa  rent_amount  property_tax   \
# 1          acept  not furnished  1200         4960            366
# ...

# %%
fig, ax = plt.subplots(figsize = (20, 7))
sns.countplot(x = "city", hue = "rooms", data = data_1)
plt.show()

# %%
data_1["total"].groupby(data_1["city"]).mean()
# Out:
# city
# Belo Horizonte    4974.924574
# Campinas          4503.387435
# Porto Alegre      4515.794937
# Rio de Janeiro    5857.987826
# São Paulo         6716.411136
# Name: total, dtype: float64

# %%
mean = data_1["total"].groupby(data_1["city"]).mean()

mean.plot(kind='bar', title='Arrests', ylabel='Mean',
         xlabel='cities', figsize=(6, 5))
# Out:
# <AxesSubplot:title={'center':'Arrests'}, xlabel='cities', ylabel='Mean'>

# %% [markdown]
# # campinas city provides more number of rooms with less average total

# %% [markdown]
# # 28. analysis of cities which gives furnished rooma with less total

# %%
data_2 = df[(df.furniture == 'furnished')]
data_2
# Out:
#                  city  area  rooms  bathroom  parking spaces  floor  \
# 0           São Paulo    70      2         1               1      7
# 8           São Paulo   152      2         2               1      3
# 9      Rio de Janeiro    35      1         1               0      2
# 10          São Paulo    26      1         1               0      2
# 13          São Paulo    55      1         1               1      2
# ...               ...   ...    ...       ...             ...    ...
# 10682    Porto Alegre   160      3         2               3      4
# 10686       São Paulo   150      3         3               2      8
# 10687    Porto Alegre    63      2         1               1      5
# 10689  Rio de Janeiro    70      3         3               0      8
# 10690  Rio de Janeiro   120      2         2               2      8
#
#           animal  furniture   hoa  rent_amount  property_tax   fire_insurance  \
# ...

# %%
fig, ax = plt.subplots(1, 2, figsize = (15, 7))
sns.histplot(x = data_2["total"], hue = data_2["city"], ax = ax[0])
sns.boxplot(x = data_2["city"] ,y = data_2["total"] , ax = ax[1])
plt.show()

# %%
data_2["total"].groupby(data_2["city"]).mean()
# Out:
# city
# Belo Horizonte    4949.231638
# Campinas          3632.072072
# Porto Alegre      3647.037618
# Rio de Janeiro    5085.221675
# São Paulo         6002.921532
# Name: total, dtype: float64

# %%
mean = data_2["total"].groupby(data_2["city"]).mean()

mean.plot(kind='bar', title='Arrests', ylabel='Mean',
         xlabel='cities', figsize=(6, 5))
# Out:
# <AxesSubplot:title={'center':'Arrests'}, xlabel='cities', ylabel='Mean'>

# %% [markdown]
# # campinas provide furnised rooms with less average total

# %% [markdown]
# # 29.analysis of cities which provide high parking space with less total

# %%
data_3 = df[(df['parking spaces']> df['parking spaces'].mean())]
data_3
# Out:
#                  city  area  rooms  bathroom  parking spaces  floor  \
# 5           São Paulo   376      3         3               7      0
# 7           São Paulo   213      4         4               4      4
# 14          São Paulo   100      2         2               2     24
# 15           Campinas   330      4         6               6      0
# 19          São Paulo   600      4         5               6      0
# ...               ...   ...    ...       ...             ...    ...
# 10683       São Paulo   280      4         4               2      5
# 10685       São Paulo    83      3         2               2     11
# 10686       São Paulo   150      3         3               2      8
# 10688       São Paulo   285      4         4               4     17
# 10690  Rio de Janeiro   120      2         2               2      8
#
#           animal      furniture   hoa  rent_amount  property_tax   \
# 5          acept  not furnished     0         8000            834
# ...

# %%
fig, ax = plt.subplots(1, 2, figsize = (15, 7))
sns.histplot(x = data_3["total"], hue = data_3["city"], ax = ax[0])
sns.boxplot(x = data_3["city"] ,y = data_3["total"] , ax = ax[1])
plt.show()

# %%
data_3["total"].groupby(data_3["city"]).mean()
# Out:
# city
# Belo Horizonte    5490.392308
# Campinas          4929.639610
# Porto Alegre      5013.265781
# Rio de Janeiro    6982.500000
# São Paulo         6828.200000
# Name: total, dtype: float64

# %%
mean = data_3["total"].groupby(data_3["city"]).mean()

mean.plot(kind='bar', title='Arrests', ylabel='Mean',
         xlabel='cities', figsize=(6, 5))
# Out:
# <AxesSubplot:title={'center':'Arrests'}, xlabel='cities', ylabel='Mean'>

# %% [markdown]
# # campinas provide parking spaces having more mean with less total

# %% [markdown]
# # 30. analysis of cities which provide more floor with less rent amount

# %%
data_4 = df[(df['floor']> df['floor'].mean())]
data_4
# Out:
#                  city  area  rooms  bathroom  parking spaces  floor  \
# 0           São Paulo    70      2         1               1      7
# 1           São Paulo   320      4         4               0     20
# 2        Porto Alegre    80      1         1               1      6
# 6      Rio de Janeiro    72      2         1               0      7
# 11           Campinas    46      1         1               1     10
# ...               ...   ...    ...       ...             ...    ...
# 10685       São Paulo    83      3         2               2     11
# 10686       São Paulo   150      3         3               2      8
# 10688       São Paulo   285      4         4               4     17
# 10689  Rio de Janeiro    70      3         3               0      8
# 10690  Rio de Janeiro   120      2         2               2      8
#
#           animal      furniture   hoa  rent_amount  property_tax   \
# 0          acept      furnished  2065         3300            211
# ...

# %%
fig, ax = plt.subplots(1, 2, figsize = (15, 7))
sns.histplot(x = data_4["rent_amount"], hue = data_4["city"], ax = ax[0])
sns.boxplot(x = data_4["city"] ,y = data_4["rent_amount"] , ax = ax[1])
plt.show()

# %%
data_3["rent_amount"].groupby(data_3["city"]).mean()
# Out:
# city
# Belo Horizonte    5312.196923
# Campinas          4092.652597
# Porto Alegre      4418.205980
# Rio de Janeiro    6673.768182
# São Paulo         6478.165172
# Name: rent_amount, dtype: float64

# %% [markdown]
# # campinas provide more floors with less rent amount
